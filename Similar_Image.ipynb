# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulnegi20/what-i-learned-in-ml/blob/master/Similar_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem 3 : Similar Image

# %%
! pip install DeepImageSearch -q
# Out:
#      |████████████████████████████████| 646 kB 13.5 MB/s
# ...

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np 
import pandas as pd

# %% [markdown]
# ###Importing the required classes from DeepImageSearch

# %%
from DeepImageSearch import Index,LoadData,SearchImage

# %% [markdown]
# ### Loading images from the drive

# %%
query_list =  LoadData().from_folder(folder_list=['/content/drive/MyDrive/test/'])
query_list[0]
# Out:
# '/content/drive/MyDrive/test/querry.jpg'

# %% [markdown]
# ### Ploting the query Image

# %%
query_image = cv2.imread(query_list[0])
#plt.imshow(cv2.cvtColor(query_image, cv2.COLOR_BGR2RGB));
image_1 = cv2.resize(query_image,(280, 480))
cv2_imshow(image_1)
# Out:
# <PIL.Image.Image image mode=RGB size=280x480 at 0x7F98225A3D50>

# %%
database_list = LoadData().from_folder(folder_list=['/content/drive/MyDrive/test/dataBase'])

# %%
Index(database_list).Start()
# Out:
# ...
# 100%|██████████| 12/12 [00:17<00:00,  1.48s/it]
# 12it [00:00, 1263.41it/s]
# Image Meta Information Saved: [meta-data-files/image_data_features.pkl]
# Saved the Indexed File:[meta-data-files/image_features_vectors.ann]

# %% [markdown]
# ### List Down the Similar images

# %%
# most similar image 
result = SearchImage().get_similar_images(image_path=query_list[0], number_of_images=1)

# %% [markdown]
# ### Ploting the result

# %%
#ploting the image
result
# Out:
# {11: '/content/drive/MyDrive/test/dataBase/14.jpg'}

# %%
#reuslt image
img = cv2.imread(result[11]) 
#plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB));
image_2 = cv2.resize(img,(280, 480))
cv2_imshow(image_2)
# Out:
# <PIL.Image.Image image mode=RGB size=280x480 at 0x7F97A36F80D0>
